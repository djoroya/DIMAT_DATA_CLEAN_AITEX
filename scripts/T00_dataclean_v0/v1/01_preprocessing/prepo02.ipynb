# %%
data_path = "../../processing/AITEX_cleaned_01.csv"

# %%
import pandas as pd

# %%
df = pd.read_csv(data_path,sep=';')

# %%
materials = df['Material'].unique()
print(materials)
print(len(materials))
# Out:
# ['COPET GP001-EASTMAN' 'PLA 6100D NATUREWORKS'
#  'PET + 3% Antivirico SUKANO' 'PET + 1% Bactiblock 101 R4.47' 'PP HS61R'
#  'PP 561R' 'PP H561R' 'rPET + CO2 Pure' 'PA B33L' 'PA6 PENTABATC'
#  'PA6 H24' 'PA6 B27' 'PET + Avanza O 0.3.%' 'rPET + CO2 Pure 3%'
#  'rPET + CO2 Pure 2.5%' 'PES + 1% BB101 R4.47' 'PLA LUMINY L130'
#  'PLA L130' 'SPH16' 'PET + 15% SPH16' 'PBT + 15% SPH16W' 'PBT + 3% Octil'
#  'PBT + 15% MB' 'TPX' 'PET + 3% Zeol Ag' 'LOWMELT 53001' 'PA H24'
#  'TPX DX350' 'ADUANITE S3001' '100%MB SP16H' 'PP + 10% Talco'
#  'PP + Talco + Verde' 'Pruebas PP Amarilleamiento' 'PP + Talco + Rojo'
#  'PA + CNT PA Nanocyl PA (H24)' 'rPET' 'rPET 2% HIPS' 'rPET 0.5% HIPS'
#  'PHB 2450 mod' 'TCP - ET' 'rPET + PTT' 'PHB 2450 mod Blanco 2%'
#  'PHB 2450 mod Azul 2%' 'PES + MNV' 'PP + FR' 'rPET tejidos + rPET' 'PA'
#  'TPC - ET LG' 'PEBAX MV 1074 SA' 'A + rPET' 'A + rPET 50/50'
#  'TPX DX350 0.5% Blanco' 'TPX DX350 0.66% Negro' 'ZK6HF' 'ZK6HF '
#  '20180 rPETD/rPET' 'rPET DEC + rPET' 'rPET DEC + rPET (50%/50%)'
#  'PHB DANIMER' 'ZK5HF PMMA' 'ZK6HF PMMA' 'PP + 07%Amarillo + 2%UV 792930'
#  'PP + 07%Amarillo + 2%UV 792930 + 4%FR LXR935'
#  'PP + 07%Rojo + 2%UV 792930' 'PP + 07%Rojo + 2%UV 792930 + 4% FR LXR935'
#  'rPET + 2% Amarillo' 'rPET Batch 1' 'TPE + 10% Plastificante'
#  'rPET DECATHLON' 'rPET 50/50' '100% NEGOMBO SIN COLOR'
#  'PEF 75:25 (0560:0491)' 'PET + PEF' '30/70 (Color/rPET)' 'PES SEMI-MAT'
#  'PES GRAFENO 5000 ppm' 'PES GRAFENO 10000 ppm'
#  'PE PURELL GA7760 + 4% Aditivo' 'NEGOMBO WHITE 30% + rPET 70%' 'BATCH 2'
#  'NEGOMBO BLACK 30% + rPET 70%' 'TPX 350' 'LLDPE ASPUN (RESINEX)'
#  'PLA + 0.1 Silano' 'PLA' 'PHB DAN 04493' 'rPET 30/70' 'COPET' 'PS 454N'
#  'ADVANITE 53001' 'TPX + Negro' 'TPE Producción' 'ABS H380' 'rPET BATCH 1'
#  'rPET BATCH 2' 'rPET BATCH 3' 'PBS' 'Reclado químico VELOR' 'PE ASPUN'
#  'SABIC M200024' 'SABIC M200056' 'PLA + CaCO3' 'MP1924 + 0.3 TiO2'
#  'MP1925 + 0.3 TiO2']
# 104

# %%
df
# Out:
#            Date    Test               Material  Nº holes / Nº filaments  \
# 0    02/03/2021  P21-30    COPET GP001-EASTMAN                     36.0
# 1    03/03/2021  P21-35    COPET GP001-EASTMAN                     48.0
# 2    03/03/2021  P21-36    COPET GP001-EASTMAN                     48.0
# 3    03/03/2021  P21-37    COPET GP001-EASTMAN                     48.0
# 4    10/03/2021  P21-38  PLA 6100D NATUREWORKS                     36.0
# ..          ...     ...                    ...                      ...
# 399  02/05/2024  P24-52            PLA + CaCO3                     72.0
# 400  02/05/2024  P24-53            PLA + CaCO3                     72.0
# 401  13/05/2024  P24-58      MP1924 + 0.3 TiO2                     72.0
# 402  13/05/2024  P24-59      MP1925 + 0.3 TiO2                     72.0
# 403  13/05/2024  P24-60      MP1925 + 0.3 TiO2                     72.0
#
#      Diameter (mm)  L/D  Filter (um)  Sand quantity (cm)  Support  \
# 0              0.4  4.0         60.0                 NaN      4.0
# 1              0.4  4.0         60.0                 2.0      2.0
# 2              0.4  4.0         60.0                 2.0      2.0
# 3              0.4  4.0         60.0                 2.0      2.0
# 4              0.3  2.0         60.0                 NaN      NaN
# ..             ...  ...          ...                 ...      ...
# 399            0.3  2.0         90.0                 2.0      2.0
# 400            0.3  2.0         90.0                 2.0      2.0
# 401            0.3  2.0         90.0                 2.0      2.0
# 402            0.3  2.0         90.0                 2.0      2.0
# 403            0.3  2.0         90.0                 2.0      2.0
#
#      Vpump (rpm)  ...  Tg2(°C)  Tg3(°C)  Quench (%)  Spin. F (rmp)  \
# 0           10.0  ...    110.0    110.0        20.0           24.0
# 1           10.7  ...    100.0     80.0        30.0           24.0
# 2           10.7  ...    100.0     90.0        30.0           24.0
# 3           10.7  ...    100.0     90.0        30.0           24.0
# 4           15.0  ...      NaN      NaN        20.0           20.0
# ..           ...  ...      ...      ...         ...            ...
# 399         19.5  ...      NaN      NaN        40.0           20.0
# 400         19.5  ...      NaN      NaN        40.0           20.0
# 401         13.0  ...      NaN      NaN         NaN           18.0
# 402         14.0  ...      NaN      NaN        10.0           16.0
# 403         14.5  ...      NaN      NaN        10.0           16.0
#
#      Height (m)  Count (dtex)  Tenacity (g/den)  Elongation (%)  \
# 0          1.40           155              0.54           44.94
# 1          1.50           170              1.64           64.69
# 2          1.50           160              1.67           73.79
# 3          1.50           140              1.99           44.83
# 4          1.30           135              2.08           55.33
# ..          ...           ...               ...             ...
# 399        1.65           220              1.70           95.00
# 400        1.65           220              1.70          100.00
# 401        1.50           133              2.16          128.00
# 402        1.60           136              2.62          130.67
# 403        1.50           148              2.90          147.00
#
#      Sand size min (um)  Sand size max (um)
# 0                   NaN                 NaN
# 1                 850.0               500.0
# 2                 850.0               500.0
# 3                 850.0               500.0
# 4                   NaN                 NaN
# ..                  ...                 ...
# 399               500.0               355.0
# 400               500.0               355.0
# 401               500.0               355.0
# 402               500.0               355.0
# 403               500.0               355.0
#
# [404 rows x 36 columns]

# %%
material = df.pop("Material")
date = df.pop("Date")
test = df.pop("Test")

# %%
df
# Out:
#      Nº holes / Nº filaments  Diameter (mm)  L/D  Filter (um)  \
# 0                       36.0            0.4  4.0         60.0
# 1                       48.0            0.4  4.0         60.0
# 2                       48.0            0.4  4.0         60.0
# 3                       48.0            0.4  4.0         60.0
# 4                       36.0            0.3  2.0         60.0
# ..                       ...            ...  ...          ...
# 399                     72.0            0.3  2.0         90.0
# 400                     72.0            0.3  2.0         90.0
# 401                     72.0            0.3  2.0         90.0
# 402                     72.0            0.3  2.0         90.0
# 403                     72.0            0.3  2.0         90.0
#
#      Sand quantity (cm)  Support  Vpump (rpm)  Vext (rpm)  TE1 (°C)  TE2 (°C)  \
# 0                   NaN      4.0         10.0        23.9     280.0     285.0
# 1                   2.0      2.0         10.7        30.2     280.0     280.0
# 2                   2.0      2.0         10.7        30.7     280.0     280.0
# 3                   2.0      2.0         10.7        30.7     280.0     280.0
# 4                   NaN      NaN         15.0        50.0     225.0     215.0
# ..                  ...      ...          ...         ...       ...       ...
# 399                 2.0      2.0         19.5        43.0      50.0      70.0
# 400                 2.0      2.0         19.5        41.0      50.0      70.0
# 401                 2.0      2.0         13.0        70.0      69.3      90.7
# 402                 2.0      2.0         14.0        45.0     154.8     111.2
# 403                 2.0      2.0         14.5        45.0     169.2     115.4
#
#      ...  Tg2(°C)  Tg3(°C)  Quench (%)  Spin. F (rmp)  Height (m)  \
# 0    ...    110.0    110.0        20.0           24.0        1.40
# 1    ...    100.0     80.0        30.0           24.0        1.50
# 2    ...    100.0     90.0        30.0           24.0        1.50
# 3    ...    100.0     90.0        30.0           24.0        1.50
# 4    ...      NaN      NaN        20.0           20.0        1.30
# ..   ...      ...      ...         ...            ...         ...
# 399  ...      NaN      NaN        40.0           20.0        1.65
# 400  ...      NaN      NaN        40.0           20.0        1.65
# 401  ...      NaN      NaN         NaN           18.0        1.50
# 402  ...      NaN      NaN        10.0           16.0        1.60
# 403  ...      NaN      NaN        10.0           16.0        1.50
#
#      Count (dtex)  Tenacity (g/den)  Elongation (%)  Sand size min (um)  \
# 0             155              0.54           44.94                 NaN
# 1             170              1.64           64.69               850.0
# 2             160              1.67           73.79               850.0
# 3             140              1.99           44.83               850.0
# 4             135              2.08           55.33                 NaN
# ..            ...               ...             ...                 ...
# 399           220              1.70           95.00               500.0
# 400           220              1.70          100.00               500.0
# 401           133              2.16          128.00               500.0
# 402           136              2.62          130.67               500.0
# 403           148              2.90          147.00               500.0
#
#      Sand size max (um)
# 0                   NaN
# 1                 500.0
# 2                 500.0
# 3                 500.0
# 4                   NaN
# ..                  ...
# 399               355.0
# 400               355.0
# 401               355.0
# 402               355.0
# 403               355.0
#
# [404 rows x 33 columns]

# %%
# histogram of the data
df.hist(bins=50, figsize=(20,15));

# %%
#show empy values summary
len_df = len(df)
print(f"Number of rows in the dataframe: {len_df}")
print("Number of empty values in each column:")
print(100*df.isna().sum())
# Out:
# Number of rows in the dataframe: 404
# Number of empty values in each column:
# Nº holes / Nº filaments    0
# Diameter (mm)              0
# L/D                        0
# Filter (um)                0
# Sand quantity (cm)         0
# Support                    0
# Vpump (rpm)                0
# Vext (rpm)                 0
# TE1 (°C)                   0
# TE2 (°C)                   0
# TD(°C)                     0
# PD(bar)                    0
# PE(bar)                    0
# VTO (m/min)                0
# VG1(m/min)                 0
# VG2(m/min)                 0
# Vwinder (m/min)            0
# Winder tension (N)         0
# Tg1(°C)                    0
# Tg3(°C)                    0
# Quench (%)                 0
# Spin. F (rmp)              0
# Height (m)                 0
# Count (dtex)               0
# Tenacity (g/den)           0
# Elongation (%)             0
# Sand size min (um)         0
# Sand size max (um)         0
# Material                   0
# dtype: int64

# %%
# correlation matrix
corr_matrix = df.corr()

# plot the correlation matrix
import matplotlib.pyplot as plt

plt.matshow(corr_matrix, cmap='jet')
# colorbar
plt.colorbar()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Calcular la matriz de correlación
corr_matrix = df.corr().abs()

# Seleccionar solo la parte superior de la matriz de correlación
upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Encontrar los pares de variables con la correlación más alta
most_correlated_pairs = upper_tri.stack().sort_values(ascending=False).head(25)
print("Pares de variables más correlacionadas:\n", most_correlated_pairs)

# Configurar subplots
fig = plt.figure(figsize=(10, 10))

fig.suptitle("Pares de variables más correlacionadas", fontsize=16)

# Graficar cada par de variables en un subplot
for idx, ((var1, var2), correlation) in enumerate(most_correlated_pairs.items()):
    plt.subplot(5, 5, idx + 1)
    sns.scatterplot(x=df[var1], y=df[var2])
    sns.regplot(x=df[var1], y=df[var2], scatter=False, color='red')  # Línea de regresión
    plt.title(f"{var1} vs {var2} (Corr: {correlation:.2f})", fontsize=8)


plt.tight_layout(rect=[0, 0, 1, 0.95])  # Ajuste para evitar que los títulos se superpongan
plt.show()
# Out:
# Pares de variables más correlacionadas:
#  VG4(m/min)          Vwinder (m/min)       0.993892
# TE3 (°C)            TE4 (°C)              0.993853
# VG3(m/min)          VG4(m/min)            0.985217
#                     Vwinder (m/min)       0.979516
# Tg1(°C)             Tg2(°C)               0.952655
# TE4 (°C)            TD(°C)                0.933186
# TE3 (°C)            TD(°C)                0.924221
# Sand size min (um)  Sand size max (um)    0.917952
# TE1 (°C)            TE2 (°C)              0.902707
# Tg2(°C)             Tg3(°C)               0.883089
# TE2 (°C)            PE(bar)               0.882257
# Tg1(°C)             Tg3(°C)               0.853756
# VTO (m/min)         VG1(m/min)            0.843442
# TE4 (°C)            Tg3(°C)               0.821094
# VG2(m/min)          VG3(m/min)            0.812977
# TE3 (°C)            Tg3(°C)               0.808809
# PD(bar)             PE(bar)               0.802794
# TE1 (°C)            PE(bar)               0.800658
# VG2(m/min)          VG4(m/min)            0.796411
#                     Vwinder (m/min)       0.792434
# Vpump (rpm)         Count (dtex)          0.787599
# TD(°C)              Tg3(°C)               0.728627
# TE4 (°C)            Tg1(°C)               0.725269
# TE3 (°C)            Tg1(°C)               0.719678
# TE4 (°C)            Tg2(°C)               0.718207
# dtype: float64

# %%
df.columns
# Out:
# Index(['Nº holes / Nº filaments', 'Diameter (mm)', 'L/D', 'Filter (um)',
#        'Sand quantity (cm)', 'Support', 'Vpump (rpm)', 'Vext (rpm)',
#        'TE1 (°C)', 'TE2 (°C)', 'TE3 (°C)', 'TE4 (°C)', 'TD(°C)', 'PD(bar)',
#        'PE(bar)', 'VTO (m/min)', 'VG1(m/min)', 'VG2(m/min)', 'VG3(m/min)',
#        'VG4(m/min)', 'Vwinder (m/min)', 'Winder tension (N)', 'Tg1(°C)',
#        'Tg2(°C)', 'Tg3(°C)', 'Quench (%)', 'Spin. F (rmp)', 'Height (m)',
#        'Count (dtex)', 'Tenacity (g/den)', 'Elongation (%)',
#        'Sand size min (um)', 'Sand size max (um)'],
#       dtype='object')

# %%
df.pop("VG3(m/min)")
df.pop("VG4(m/min)")
df.pop("TE3 (°C)")
df.pop("TE4 (°C)")

df.pop("Tg2(°C)")
# Out:
# 0      110.0
# 1      100.0
# 2      100.0
# 3      100.0
# 4        NaN
#        ...
# 399      NaN
# 400      NaN
# 401      NaN
# 402      NaN
# 403      NaN
# Name: Tg2(°C), Length: 404, dtype: float64

# %%
df
# Out:
#      Nº holes / Nº filaments  Diameter (mm)  L/D  Filter (um)  \
# 0                       36.0            0.4  4.0         60.0
# 1                       48.0            0.4  4.0         60.0
# 2                       48.0            0.4  4.0         60.0
# 3                       48.0            0.4  4.0         60.0
# 4                       36.0            0.3  2.0         60.0
# ..                       ...            ...  ...          ...
# 399                     72.0            0.3  2.0         90.0
# 400                     72.0            0.3  2.0         90.0
# 401                     72.0            0.3  2.0         90.0
# 402                     72.0            0.3  2.0         90.0
# 403                     72.0            0.3  2.0         90.0
#
#      Sand quantity (cm)  Support  Vpump (rpm)  Vext (rpm)  TE1 (°C)  TE2 (°C)  \
# 0                   NaN      4.0         10.0        23.9     280.0     285.0
# 1                   2.0      2.0         10.7        30.2     280.0     280.0
# 2                   2.0      2.0         10.7        30.7     280.0     280.0
# 3                   2.0      2.0         10.7        30.7     280.0     280.0
# 4                   NaN      NaN         15.0        50.0     225.0     215.0
# ..                  ...      ...          ...         ...       ...       ...
# 399                 2.0      2.0         19.5        43.0      50.0      70.0
# 400                 2.0      2.0         19.5        41.0      50.0      70.0
# 401                 2.0      2.0         13.0        70.0      69.3      90.7
# 402                 2.0      2.0         14.0        45.0     154.8     111.2
# 403                 2.0      2.0         14.5        45.0     169.2     115.4
#
#      ...  Tg1(°C)  Tg3(°C)  Quench (%)  Spin. F (rmp)  Height (m)  \
# 0    ...     85.0    110.0        20.0           24.0        1.40
# 1    ...     85.0     80.0        30.0           24.0        1.50
# 2    ...     85.0     90.0        30.0           24.0        1.50
# 3    ...     85.0     90.0        30.0           24.0        1.50
# 4    ...      NaN      NaN        20.0           20.0        1.30
# ..   ...      ...      ...         ...            ...         ...
# 399  ...      NaN      NaN        40.0           20.0        1.65
# 400  ...      NaN      NaN        40.0           20.0        1.65
# 401  ...      NaN      NaN         NaN           18.0        1.50
# 402  ...      NaN      NaN        10.0           16.0        1.60
# 403  ...      NaN      NaN        10.0           16.0        1.50
#
#      Count (dtex)  Tenacity (g/den)  Elongation (%)  Sand size min (um)  \
# 0             155              0.54           44.94                 NaN
# 1             170              1.64           64.69               850.0
# 2             160              1.67           73.79               850.0
# 3             140              1.99           44.83               850.0
# 4             135              2.08           55.33                 NaN
# ..            ...               ...             ...                 ...
# 399           220              1.70           95.00               500.0
# 400           220              1.70          100.00               500.0
# 401           133              2.16          128.00               500.0
# 402           136              2.62          130.67               500.0
# 403           148              2.90          147.00               500.0
#
#      Sand size max (um)
# 0                   NaN
# 1                 500.0
# 2                 500.0
# 3                 500.0
# 4                   NaN
# ..                  ...
# 399               355.0
# 400               355.0
# 401               355.0
# 402               355.0
# 403               355.0
#
# [404 rows x 28 columns]

# %%
# histogram of the data
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'Nº holes / Nº filaments'}>,
#         <Axes: title={'center': 'Diameter (mm)'}>,
#         <Axes: title={'center': 'L/D'}>,
#         <Axes: title={'center': 'Filter (um)'}>,
#         <Axes: title={'center': 'Sand quantity (cm)'}>],
#        [<Axes: title={'center': 'Support'}>,
#         <Axes: title={'center': 'Vpump (rpm)'}>,
#         <Axes: title={'center': 'Vext (rpm)'}>,
#         <Axes: title={'center': 'TE1 (°C)'}>,
#         <Axes: title={'center': 'TE2 (°C)'}>],
#        [<Axes: title={'center': 'TD(°C)'}>,
#         <Axes: title={'center': 'PD(bar)'}>,
#         <Axes: title={'center': 'PE(bar)'}>,
#         <Axes: title={'center': 'VTO (m/min)'}>,
#         <Axes: title={'center': 'VG1(m/min)'}>],
#        [<Axes: title={'center': 'VG2(m/min)'}>,
#         <Axes: title={'center': 'Vwinder (m/min)'}>,
#         <Axes: title={'center': 'Winder tension (N)'}>,
#         <Axes: title={'center': 'Tg1(°C)'}>,
#         <Axes: title={'center': 'Tg3(°C)'}>],
#        [<Axes: title={'center': 'Quench (%)'}>,
#         <Axes: title={'center': 'Spin. F (rmp)'}>,
#         <Axes: title={'center': 'Height (m)'}>,
#         <Axes: title={'center': 'Count (dtex)'}>,
#         <Axes: title={'center': 'Tenacity (g/den)'}>],
#        [<Axes: title={'center': 'Elongation (%)'}>,
#         <Axes: title={'center': 'Sand size min (um)'}>,
#         <Axes: title={'center': 'Sand size max (um)'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Calcular la matriz de correlación
corr_matrix = df.corr().abs()

# Seleccionar solo la parte superior de la matriz de correlación
upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Encontrar los pares de variables con la correlación más alta
most_correlated_pairs = upper_tri.stack().sort_values(ascending=False).head(16)
print("Pares de variables más correlacionadas:\n", most_correlated_pairs)

# Configurar subplots
fig = plt.figure(figsize=(10, 10))

fig.suptitle("Pares de variables más correlacionadas", fontsize=16)

# Graficar cada par de variables en un subplot
for idx, ((var1, var2), correlation) in enumerate(most_correlated_pairs.items()):
    plt.subplot(4, 4, idx + 1)
    sns.scatterplot(x=df[var1], y=df[var2])
    sns.regplot(x=df[var1], y=df[var2], scatter=False, color='red')  # Línea de regresión
    plt.title(f"{var1} vs {var2} (Corr: {correlation:.2f})", fontsize=8)


plt.tight_layout(rect=[0, 0, 1, 0.95])  # Ajuste para evitar que los títulos se superpongan
plt.show()
# Out:
# Pares de variables más correlacionadas:
#  Sand size min (um)  Sand size max (um)    0.917952
# TE1 (°C)            TE2 (°C)              0.902707
# TE2 (°C)            PE(bar)               0.882257
# Tg1(°C)             Tg3(°C)               0.853756
# VTO (m/min)         VG1(m/min)            0.843442
# PD(bar)             PE(bar)               0.802794
# TE1 (°C)            PE(bar)               0.800658
# VG2(m/min)          Vwinder (m/min)       0.792434
# Vpump (rpm)         Count (dtex)          0.787599
# TD(°C)              Tg3(°C)               0.728627
# TE2 (°C)            PD(bar)               0.711006
# Quench (%)          Height (m)            0.687824
# Diameter (mm)       L/D                   0.681765
# Tg3(°C)             Elongation (%)        0.645277
# TE1 (°C)            PD(bar)               0.644615
# VG1(m/min)          VG2(m/min)            0.641598
# dtype: float64

# %%
# nan -> mean of the column
df.fillna(df.mean(), inplace=True)
# remove nan
#df.dropna(inplace=True)

# %%
df
# Out:
#      Nº holes / Nº filaments  Diameter (mm)  L/D  Filter (um)  \
# 0                       36.0            0.4  4.0         60.0
# 1                       48.0            0.4  4.0         60.0
# 2                       48.0            0.4  4.0         60.0
# 3                       48.0            0.4  4.0         60.0
# 4                       36.0            0.3  2.0         60.0
# ..                       ...            ...  ...          ...
# 399                     72.0            0.3  2.0         90.0
# 400                     72.0            0.3  2.0         90.0
# 401                     72.0            0.3  2.0         90.0
# 402                     72.0            0.3  2.0         90.0
# 403                     72.0            0.3  2.0         90.0
#
#      Sand quantity (cm)    Support  Vpump (rpm)  Vext (rpm)  TE1 (°C)  \
# 0              2.563319   4.000000         10.0        23.9     280.0
# 1              2.000000   2.000000         10.7        30.2     280.0
# 2              2.000000   2.000000         10.7        30.7     280.0
# 3              2.000000   2.000000         10.7        30.7     280.0
# 4              2.563319  35.612648         15.0        50.0     225.0
# ..                  ...        ...          ...         ...       ...
# 399            2.000000   2.000000         19.5        43.0      50.0
# 400            2.000000   2.000000         19.5        41.0      50.0
# 401            2.000000   2.000000         13.0        70.0      69.3
# 402            2.000000   2.000000         14.0        45.0     154.8
# 403            2.000000   2.000000         14.5        45.0     169.2
#
#      TE2 (°C)  ...    Tg1(°C)     Tg3(°C)  Quench (%)  Spin. F (rmp)  \
# 0       285.0  ...  85.000000  110.000000   20.000000           24.0
# 1       280.0  ...  85.000000   80.000000   30.000000           24.0
# 2       280.0  ...  85.000000   90.000000   30.000000           24.0
# 3       280.0  ...  85.000000   90.000000   30.000000           24.0
# 4       215.0  ...  85.532544  111.516129   20.000000           20.0
# ..        ...  ...        ...         ...         ...            ...
# 399      70.0  ...  85.532544  111.516129   40.000000           20.0
# 400      70.0  ...  85.532544  111.516129   40.000000           20.0
# 401      90.7  ...  85.532544  111.516129   39.583541           18.0
# 402     111.2  ...  85.532544  111.516129   10.000000           16.0
# 403     115.4  ...  85.532544  111.516129   10.000000           16.0
#
#      Height (m)  Count (dtex)  Tenacity (g/den)  Elongation (%)  \
# 0          1.40           155              0.54           44.94
# 1          1.50           170              1.64           64.69
# 2          1.50           160              1.67           73.79
# 3          1.50           140              1.99           44.83
# 4          1.30           135              2.08           55.33
# ..          ...           ...               ...             ...
# 399        1.65           220              1.70           95.00
# 400        1.65           220              1.70          100.00
# 401        1.50           133              2.16          128.00
# 402        1.60           136              2.62          130.67
# 403        1.50           148              2.90          147.00
#
#      Sand size min (um)  Sand size max (um)
# 0            560.574468          375.340426
# 1            850.000000          500.000000
# 2            850.000000          500.000000
# 3            850.000000          500.000000
# 4            560.574468          375.340426
# ..                  ...                 ...
# 399          500.000000          355.000000
# 400          500.000000          355.000000
# 401          500.000000          355.000000
# 402          500.000000          355.000000
# 403          500.000000          355.000000
#
# [404 rows x 28 columns]

# %%
df["Material"] = material

# description of the data
df.describe()
df.to_csv("processing/AITEX_cleaned_02.csv", sep=';', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[19], line 5
#       3 # description of the data
#       4 df.describe()
# ----> 5 df.to_csv("processing/AITEX_cleaned_02.csv", sep=';', index=False)
#
# File ~/projects/DIMAT/M03_AITEX_YARN/app_gitlab/strength_semicrystalline_polymer_app/.conda/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/projects/DIMAT/M03_AITEX_YARN/app_gitlab/strength_semicrystalline_polymer_app/.conda/lib/python3.11/site-packages/pandas/core/generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)   3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~/projects/DIMAT/M03_AITEX_YARN/app_gitlab/strength_semicrystalline_polymer_app/.conda/lib/python3.11/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)   1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/projects/DIMAT/M03_AITEX_YARN/app_gitlab/strength_semicrystalline_polymer_app/.conda/lib/python3.11/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)    267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~/projects/DIMAT/M03_AITEX_YARN/app_gitlab/strength_semicrystalline_polymer_app/.conda/lib/python3.11/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/projects/DIMAT/M03_AITEX_YARN/app_gitlab/strength_semicrystalline_polymer_app/.conda/lib/python3.11/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'processing'
